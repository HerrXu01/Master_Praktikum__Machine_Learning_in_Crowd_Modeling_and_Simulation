# %% [markdown]
# # Task 3, Training a Variational Auto-Encoder on MNIST

# %% [markdown]
# ## 1. Initial Setup
#
# For task 3 we used Pytorch, Numpy and Matplotlib.

# %%
import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.utils
import torch.distributions
import torchvision
import numpy as np
import matplotlib.pyplot as plt
# plt.rcParams['figure.dpi'] = 200

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## 2.Define the VAE model

# %%
class VariationalEncoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalEncoder, self).__init__()
        self.linear1 = nn.Linear(784, 256)
        self.linear2 = nn.Linear(256, 256)
        self.linear3 = nn.Linear(256, latent_dims)
        self.linear4 = nn.Linear(256, latent_dims)

        # self.N = torch.distributions.Normal(0, 1)
        # self.N.loc = self.N.loc.cpu() # hack to get sampling on the CPU
        # self.N.scale = self.N.scale.cpu()
        self.kl = 0
        
    def forward(self, x):
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        mu =  self.linear3(x)
        sigma = self.linear4(x)
        # sigma = torch.exp(self.linear3(x))
        # z = mu + sigma*self.N.sample(mu.shape)
        # self.kl = (sigma**2 + mu**2 - torch.log(sigma) - 1/2).sum()
        # print(z)
        return mu, sigma
        
class Decoder(nn.Module):
    def __init__(self, latent_dims):
        super(Decoder, self).__init__()
        self.linear1 = nn.Linear(latent_dims, 256)
        self.linear2 = nn.Linear(256, 256)
        self.linear3 = nn.Linear(256, 784)

    def forward(self, z):
        z = F.relu(self.linear1(z))
        z = F.relu(self.linear2(z))
        z = torch.sigmoid(self.linear3(z))
        return z
        # return z.reshape((-1, 1, 28, 28))

class VariationalAutoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = VariationalEncoder(latent_dims)
        self.decoder = Decoder(latent_dims)
        
    def reparameterize(self, mu, sigma):
        std = torch.exp(0.5 * sigma)
        eps = torch.randn_like(std)
        z = mu + eps * std
        return z
        
    def forward(self, x):
        # print(x)
        mu, sigma = self.encoder(x)
        z = self.reparameterize(mu, sigma)
        # print('z2:',z)
        x_recon = self.decoder(z)
        # print('xrecon2:',x_recon)
        return x_recon, mu, sigma

    def generate_samples(self, num_samples):
        z = torch.randn(num_samples,latent_dims).to(device)
        samples = self.decoder(z)
        return samples

# %% [markdown]
# ## 3. Define functions

# %%
def elbo_loss(x, x_hat, mu, log_var):
    #Reconstruction
    x=x.view(-1, 784)
    # print('x_recon1:',x_hat)
    x=torch.sigmoid(x)
    # print('x1:',x)
    recon_loss = F.binary_cross_entropy(x_hat, x, reduction='sum')

    #Regularisation
    kl_div = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())

    return recon_loss + kl_div

# %%
# train_losses = []
def train(autoencoder, data, epochs):
    opt = torch.optim.Adam(autoencoder.parameters(),lr=0.001) # Set up the optimizer
    autoencoder.train()
    train_losses = []
    for epoch in range(epochs):
        total_loss = 0
        for x, y in data:
            x = x.view(-1, 784).to(device) # CPU
            # print('x2:',x.shape)
            # print('x2:',x)
            opt.zero_grad()
            # x_hat= autoencoder(x)
            x_hat, mu, logvar = autoencoder(x)
            # print('x_recon2:',x_hat.shape)
            # print(mu.shape)
            # print(logvar.shape)
            # loss = ((x - x_hat)**2).sum()+ autoencoder.encoder.kl
            loss =elbo_loss(x, x_hat, mu, logvar)
            loss.backward()
            opt.step()
            total_loss += loss.item()
        total_loss = total_loss / len(data.dataset)
        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {total_loss:.4f}')
        train_losses.append(total_loss)
    return autoencoder,train_losses

def test(autoencoder, data, epochs):
    autoencoder.eval()
    test_losses = []
    with torch.no_grad():
        for epoch in range(epochs):
            autoencoder.eval()
            epoch_loss = 0.0
            for x, y in data:
                x = x.to(device) # CPU
                x_hat,mu, logvar = autoencoder(x)
                # x_hat = autoencoder(x)
                loss =elbo_loss(x, x_hat, mu, logvar)
                epoch_loss +=  loss.item()
            epoch_loss = epoch_loss / len(data.dataset)
            print(f'Epoch {epoch+1}/{epochs}, Test Loss: {epoch_loss:.4f}')
            test_losses.append(epoch_loss)
    return test_losses

# %%
#plot the latent representation
def plot_latent(autoencoder, data, num_batches=128):
    for i, (x, y) in enumerate(data): 
        x = x.view(-1,784).to(device)
        z,j = autoencoder.encoder(x)
        z = z.to('cpu').detach().numpy() 
        plt.scatter(z[:, 0], z[:, 1], c=y, cmap='tab10') 
    plt.colorbar()
    plt.title('Latent Representation')
    plt.xlabel('Latent Dimension 1')
    plt.ylabel('Latent Dimension 2')

# %%
#plot reconstructed digits and the corresponding original ones
def plot_reconstructed(autoencoder, data, num_digits=15):
    for batch in data:
        x, y = batch
        break 
    x = x.to(device) 
    z,i,j = autoencoder(x)
    x = x.view(-1, 28, 28).cpu().numpy() 
    z = z.view(-1, 28, 28).cpu().detach().numpy()  
    #Original Digits
    fig, axes = plt.subplots(3, 5,figsize=(8, 4))
    for i in range(15):
        row = i // 5  # Calculate the row index
        col = i % 5   # Calculate the column index
        axes[row, col].imshow(x[i])  # Display the image
        axes[row, col].axis('off')   
    plt.suptitle('Original Digits')
    
    #Reconstructed Digits
    fig, axes = plt.subplots(3, 5,figsize=(8, 4))
    for i in range(15):
        row = i // 5  # Calculate the row index
        col = i % 5   # Calculate the column index
        axes[row, col].imshow(z[i])  # Display the image
        axes[row, col].axis('off') 
    plt.suptitle('Reconstructed Digits')
    plt.show()

# %%
#plot generated digits
def plot_generated(autoencoder, num_samples=15):
    z = autoencoder.generate_samples(num_samples) 
    z = z.view(-1, 28, 28).cpu().detach().numpy() 

    fig, axes = plt.subplots(3, 5,figsize=(8, 4))
    for i in range(15):
        row = i // 5  # Calculate the row index
        col = i % 5   # Calculate the column index
        axes[row, col].imshow(z[i])  # Display the image
        axes[row, col].axis('off') 
    plt.suptitle('Generated Digits')
    plt.show()

# %%
def plot_losses(train_losses,test_losses,epochs):
    plt.figure(figsize=(8, 6))
    print('Train Loss',train_losses)
    print('Test Loss',test_losses)
    plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
    plt.plot(range(1, epochs+1), test_losses, label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Test Loss (Negative ELBO)')
    plt.title('Test Loss Curve')
    plt.legend()
    plt.show()

# %% [markdown]
# ## 4.Dataset
# Load the MNIST dataset and create data loaders

# %%
train_data = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('./data',
                                   train=True,
               transform=torchvision.transforms.Compose([
                         torchvision.transforms.ToTensor(), # first, convert image to PyTorch tensor
                         torchvision.transforms.Normalize((0.1307,), (0.3081,)) # normalize inputs
                ]),
               download=True),
        batch_size=128,
        shuffle=True)

test_data = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('./data',
                                   train=False,
               transform=torchvision.transforms.Compose([
                         torchvision.transforms.ToTensor(), # first, convert image to PyTorch tensor
                         torchvision.transforms.Normalize((0.1307,), (0.3081,)) # normalize inputs, mean=mean/255, std=std/255
                ]),
               download=True),
        batch_size=128,
        shuffle=True)

# %% [markdown]
# ## 5. Training and Visualization

# %%
latent_dims = 2  # Dimension of the latent space

# latent_dims = 2 # Dimension of the latent space
vae = VariationalAutoencoder(latent_dims).to(device)

# %%
#epoch 50
epochs = 50
vae,train_losses = train(vae, train_data,epochs)
test_losses = test(vae, train_data, epochs)
print('train',len(train_losses))
# print(train_losses)
print('test',len(test_losses))
plot_losses(train_losses,test_losses,epochs)
# Out:
# Epoch 1/50, Train Loss: 522.1761
# Epoch 2/50, Train Loss: 518.5526
# Epoch 3/50, Train Loss: 517.5931
# Epoch 4/50, Train Loss: 517.0103
# Epoch 5/50, Train Loss: 516.6069
# Epoch 6/50, Train Loss: 516.3074
# Epoch 7/50, Train Loss: 516.0461
# Epoch 8/50, Train Loss: 515.8830
# Epoch 9/50, Train Loss: 515.6962
# Epoch 10/50, Train Loss: 515.5347
# Epoch 11/50, Train Loss: 515.4159
# Epoch 12/50, Train Loss: 515.3269
# Epoch 13/50, Train Loss: 515.2261
# Epoch 14/50, Train Loss: 515.1153
# Epoch 15/50, Train Loss: 515.0701
# Epoch 16/50, Train Loss: 515.0253
# Epoch 17/50, Train Loss: 514.9690
# Epoch 18/50, Train Loss: 514.8868
# Epoch 19/50, Train Loss: 514.8610
# Epoch 20/50, Train Loss: 514.7811
# Epoch 21/50, Train Loss: 514.7514
# Epoch 22/50, Train Loss: 514.7130
# Epoch 23/50, Train Loss: 514.6956
# Epoch 24/50, Train Loss: 514.6488
# Epoch 25/50, Train Loss: 514.6187
# Epoch 26/50, Train Loss: 514.6195
# Epoch 27/50, Train Loss: 514.5782
# Epoch 28/50, Train Loss: 514.5325
# Epoch 29/50, Train Loss: 514.4671
# Epoch 30/50, Train Loss: 514.5329
# Epoch 31/50, Train Loss: 514.4076
# Epoch 32/50, Train Loss: 514.4358
# Epoch 33/50, Train Loss: 514.3834
# Epoch 34/50, Train Loss: 514.3671
# Epoch 35/50, Train Loss: 514.3759
# Epoch 36/50, Train Loss: 514.3516
# Epoch 37/50, Train Loss: 514.3376
# Epoch 38/50, Train Loss: 514.3147
# Epoch 39/50, Train Loss: 514.2812
# Epoch 40/50, Train Loss: 514.2554
# Epoch 41/50, Train Loss: 514.2394
# Epoch 42/50, Train Loss: 514.2455
# Epoch 43/50, Train Loss: 514.2608
# Epoch 44/50, Train Loss: 514.2380
# Epoch 45/50, Train Loss: 514.2083
# Epoch 46/50, Train Loss: 514.1788
# Epoch 47/50, Train Loss: 514.1885
# Epoch 48/50, Train Loss: 514.2088
# Epoch 49/50, Train Loss: 514.1934
# Epoch 50/50, Train Loss: 514.1827
# Epoch 1/50, Test Loss: 514.1951
# Epoch 2/50, Test Loss: 514.1833
# Epoch 3/50, Test Loss: 514.1981
# Epoch 4/50, Test Loss: 514.1955
# Epoch 5/50, Test Loss: 514.1810
# Epoch 6/50, Test Loss: 514.1892
# Epoch 7/50, Test Loss: 514.1985
# Epoch 8/50, Test Loss: 514.1941
# Epoch 9/50, Test Loss: 514.1986
# Epoch 10/50, Test Loss: 514.2068
# Epoch 11/50, Test Loss: 514.2010
# Epoch 12/50, Test Loss: 514.1946
# Epoch 13/50, Test Loss: 514.2088
# Epoch 14/50, Test Loss: 514.1944
# Epoch 15/50, Test Loss: 514.1767
# Epoch 16/50, Test Loss: 514.2147
# Epoch 17/50, Test Loss: 514.1925
# Epoch 18/50, Test Loss: 514.2059
# Epoch 19/50, Test Loss: 514.1952
# Epoch 20/50, Test Loss: 514.1958
# Epoch 21/50, Test Loss: 514.2033
# Epoch 22/50, Test Loss: 514.2016
# Epoch 23/50, Test Loss: 514.1889
# Epoch 24/50, Test Loss: 514.2012
# Epoch 25/50, Test Loss: 514.1884
# Epoch 26/50, Test Loss: 514.2002
# Epoch 27/50, Test Loss: 514.1896
# Epoch 28/50, Test Loss: 514.1925
# Epoch 29/50, Test Loss: 514.1868
# Epoch 30/50, Test Loss: 514.1874
# Epoch 31/50, Test Loss: 514.2008
# Epoch 32/50, Test Loss: 514.1937
# Epoch 33/50, Test Loss: 514.2080
# Epoch 34/50, Test Loss: 514.2029
# Epoch 35/50, Test Loss: 514.1868
# Epoch 36/50, Test Loss: 514.1964
# Epoch 37/50, Test Loss: 514.1970
# Epoch 38/50, Test Loss: 514.1900
# Epoch 39/50, Test Loss: 514.2114
# Epoch 40/50, Test Loss: 514.1889
# Epoch 41/50, Test Loss: 514.1985
# Epoch 42/50, Test Loss: 514.1917
# Epoch 43/50, Test Loss: 514.1886
# Epoch 44/50, Test Loss: 514.1938
# Epoch 45/50, Test Loss: 514.2130
# Epoch 46/50, Test Loss: 514.1961
# Epoch 47/50, Test Loss: 514.2122
# Epoch 48/50, Test Loss: 514.2074
# Epoch 49/50, Test Loss: 514.2231
# Epoch 50/50, Test Loss: 514.1895
# train 50
# test 50
# Train Loss [522.1760559895833, 518.5525802083333, 517.5930608723959, 517.01031171875, 516.6069149088542, 516.3073876953125, 516.0460869791667, 515.8830289713542, 515.6961813151041, 515.5347353515625, 515.4158738932292, 515.3269295572917, 515.2260682942708, 515.115331640625, 515.0701354817709, 515.0252956380208, 514.9690001302083, 514.8867728515625, 514.8610049479166, 514.7811311848958, 514.7514270833333, 514.7130242838541, 514.6955748046875, 514.64884375, 514.618687890625, 514.6194572916667, 514.5782057291667, 514.5325295572917, 514.4671091145833, 514.5329005208333, 514.407640234375, 514.4358169921875, 514.3834263020833, 514.3670541666667, 514.3759321614583, 514.3515709635417, 514.3375779296875, 514.3146892578125, 514.281165234375, 514.2554158854167, 514.2394364583333, 514.2455431640625, 514.2607765625, 514.2379989583334, 514.20829375, 514.178752734375, 514.1884802734374, 514.2088427734375, 514.1934352864583, 514.1826865234375]
# Test Loss [514.1950934895833, 514.1833077473958, 514.1981051432292, 514.1955042317709, 514.1810470703125, 514.1891826822916, 514.1984798828125, 514.194056640625, 514.1986115885417, 514.2067868489584, 514.2009811197917, 514.1945705078125, 514.2087599609375, 514.1944067708333, 514.176725, 514.2147168619791, 514.192479296875, 514.2058815755208, 514.1952192708334, 514.1957809895833, 514.2033311197916, 514.2015516276042, 514.1888673828125, 514.2012175130209, 514.1883585286458, 514.2001944661458, 514.1896356770833, 514.1925057291667, 514.1868373697916, 514.1874365885417, 514.20080703125, 514.193680859375, 514.207981640625, 514.2029302083333, 514.1867541015625, 514.1963818359375, 514.1970432942709, 514.1900440104166, 514.211437109375, 514.1889411458334, 514.1984868489583, 514.1916647135416, 514.1885608723958, 514.1937813151042, 514.2130299479167, 514.19607109375, 514.212226953125, 514.2074127604167, 514.2230670572917, 514.1895130859375]
