# %% [markdown]
# # Task 3, Training a Variational Auto-Encoder on MNIST

# %% [markdown]
# ## 1. Initial Setup
#
# For task 3 we used Pytorch, Numpy and Matplotlib.

# %%
import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.utils
import torch.distributions
import torchvision
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 200

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## 2.Define the VAE model

# %%
class VariationalEncoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalEncoder, self).__init__()
        self.linear1 = nn.Linear(784, 256)
        self.linear2 = nn.Linear(256, 256)
        self.linear3 = nn.Linear(256, latent_dims)
        self.linear4 = nn.Linear(256, latent_dims)
        self.kl = 0
        
    def forward(self, x):
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        mu =  self.linear3(x)
        sigma = self.linear4(x)
        return mu, sigma

class Decoder(nn.Module):
    def __init__(self, latent_dims):
        super(Decoder, self).__init__()
        self.linear1 = nn.Linear(latent_dims, 256)
        self.linear2 = nn.Linear(256, 256)
        self.linear3 = nn.Linear(256, 784)

    def forward(self, z):
        z = F.relu(self.linear1(z))
        z = F.relu(self.linear2(z))
        z = torch.sigmoid(self.linear3(z))
        return z

class VariationalAutoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = VariationalEncoder(latent_dims)
        self.decoder = Decoder(latent_dims)
        
    def reparameterize(self, mu, sigma):
        std = torch.exp(0.5 * sigma)
        eps = torch.randn_like(std)
        z = mu + eps * std
        return z
        
    def forward(self, x):
        # print(x)
        mu, sigma = self.encoder(x)
        z = self.reparameterize(mu, sigma)
        # print('z2:',z)
        x_recon = self.decoder(z)
        # print('xrecon2:',x_recon)
        return x_recon, mu, sigma

    def generate_samples(self, num_samples):
        z = torch.randn(num_samples,latent_dims).to(device)
        samples = self.decoder(z)
        return samples

# %% [markdown]
# ## 3. Define functions

# %%
def elbo_loss(x, x_hat, mu, log_var):
    #Reconstruction
    x=x.view(-1, 784)
    # print('x_recon1:',x_hat)
    x=torch.sigmoid(x)
    # print('x1:',x)
    recon_loss = F.binary_cross_entropy(x_hat, x, reduction='sum')

    #Regularisation
    kl_div = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())

    return recon_loss + kl_div

# %%
def train(autoencoder, data, epochs):
    opt = torch.optim.Adam(autoencoder.parameters(),lr=0.001) # Set up the optimizer
    autoencoder.train()
    train_losses = []
    for epoch in range(epochs):
        total_loss = 0
        for x, y in data:
            x = x.view(-1, 784).to(device) # CPU
            # print('x2:',x.shape)
            # print('x2:',x)
            opt.zero_grad()
            x_hat, mu, logvar = autoencoder(x)
            # print('x_recon2:',x_hat.shape)
            # print(mu.shape)
            # print(logvar.shape)
            loss =elbo_loss(x, x_hat, mu, logvar)
            loss.backward()
            opt.step()
            total_loss += loss.item()
        total_loss = total_loss / len(data.dataset)
        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {total_loss:.4f}')
        train_losses.append(total_loss)
    return autoencoder,train_losses
    
def test(autoencoder, data, epochs):
    # autoencoder.eval()
    test_losses = []
    with torch.no_grad():
        for epoch in range(epochs):
            autoencoder.eval()
            epoch_loss = 0.0
            for x, y in data:
                x = x.to(device) # CPU
                x_hat,mu, logvar = autoencoder(x)
                # x_hat = autoencoder(x)
                loss =elbo_loss(x, x_hat, mu, logvar)
                epoch_loss +=  loss.item()
            epoch_loss = epoch_loss / len(data.dataset)
            print(f'Epoch {epoch+1}/{epochs}, Test Loss: {epoch_loss:.4f}')
            test_losses.append(epoch_loss)
    return test_losses

# %%
#plot the latent representation
def plot_latent(autoencoder, data, num_batches=128):
    for i, (x, y) in enumerate(data): 
        x = x.view(-1,784).to(device)
        z,j = autoencoder.encoder(x)
        z = z.to('cpu').detach().numpy() 
        plt.scatter(z[:, 0], z[:, 1], c=y, cmap='tab10') 
    plt.colorbar()
    plt.title('Latent Representation')
    plt.xlabel('Latent Dimension 1')
    plt.ylabel('Latent Dimension 2')

# %%
#plot reconstructed digits and the corresponding original ones
def plot_reconstructed(autoencoder, data, num_digits=15):
    for batch in data:
        x, y = batch
        break 
    x = x.to(device) 
    z,i,j = autoencoder(x)
    x = x.view(-1, 28, 28).cpu().numpy() 
    z = z.view(-1, 28, 28).cpu().detach().numpy()  
    #Original Digits
    fig, axes = plt.subplots(3, 5,figsize=(8, 4))
    for i in range(15):
        row = i // 5  # Calculate the row index
        col = i % 5   # Calculate the column index
        axes[row, col].imshow(x[i])  # Display the image
        axes[row, col].axis('off')   
    plt.suptitle('Original Digits')
    
    #Reconstructed Digits
    fig, axes = plt.subplots(3, 5,figsize=(8, 4))
    for i in range(15):
        row = i // 5  # Calculate the row index
        col = i % 5   # Calculate the column index
        axes[row, col].imshow(z[i])  # Display the image
        axes[row, col].axis('off') 
    plt.suptitle('Reconstructed Digits')
    plt.show()

# %%
#plot generated digits
def plot_generated(autoencoder, num_samples=15):
    z = autoencoder.generate_samples(num_samples) 
    z = z.view(-1, 28, 28).cpu().detach().numpy() 

    fig, axes = plt.subplots(3, 5,figsize=(8, 4))
    for i in range(15):
        row = i // 5  # Calculate the row index
        col = i % 5   # Calculate the column index
        axes[row, col].imshow(z[i])  # Display the image
        axes[row, col].axis('off') 
    plt.suptitle('Generated Digits')
    plt.show()

# %%
def plot_losses(train_losses,test_losses,epochs):
    plt.figure(figsize=(8, 6))
    print('Train Loss',train_losses)
    print('Test Loss',test_losses)
    plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
    plt.plot(range(1, epochs+1), test_losses, label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Test Loss (Negative ELBO)')
    plt.title('Test Loss Curve')
    plt.legend()
    plt.show()

# %% [markdown]
# ## 4.Dataset
# Load the MNIST dataset and create data loaders

# %%
train_data = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('./data',
                                   train=True,
               transform=torchvision.transforms.Compose([
                         torchvision.transforms.ToTensor(), # first, convert image to PyTorch tensor
                         torchvision.transforms.Normalize((0.1307,), (0.3081,)) # normalize inputs
                ]),
               download=True),
        batch_size=128,
        shuffle=True)

test_data = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('./data',
                                   train=False,
               transform=torchvision.transforms.Compose([
                         torchvision.transforms.ToTensor(), # first, convert image to PyTorch tensor
                         torchvision.transforms.Normalize((0.1307,), (0.3081,)) # normalize inputs, mean=mean/255, std=std/255
                ]),
               download=True),
        batch_size=128,
        shuffle=False)

# %% [markdown]
# ## 5. Training and Visualization

# %%
latent_dims = 2  # Dimension of the latent space
vae = VariationalAutoencoder(latent_dims).to(device)

# %%
#epoch 1
epochs = 1
vae,train_losses1 = train(vae, train_data,epochs)
plot_latent(vae, test_data)
plot_reconstructed(vae, test_data)
plot_generated(vae)
# Out:
# Epoch 1/1, Train Loss: 522.1761

# %%
#epoch 5
epochs = 5
vae,train_losses5 = train(vae, train_data,epochs)
plot_latent(vae, test_data)
plot_reconstructed(vae, test_data)
plot_generated(vae)
# Out:
# Epoch 1/5, Train Loss: 518.5113
# Epoch 2/5, Train Loss: 517.5267
# Epoch 3/5, Train Loss: 516.9013
# Epoch 4/5, Train Loss: 516.5104
# Epoch 5/5, Train Loss: 516.2247

# %%
#epoch 25
epochs = 25
vae,train_losses25 = train(vae, train_data,epochs)
plot_latent(vae, test_data)
plot_reconstructed(vae, test_data)
plot_generated(vae)
# Out:
# Epoch 1/25, Train Loss: 515.9708
# Epoch 2/25, Train Loss: 515.7733
# Epoch 3/25, Train Loss: 515.6006
# Epoch 4/25, Train Loss: 515.4610
# Epoch 5/25, Train Loss: 515.3926
# Epoch 6/25, Train Loss: 515.2431
# Epoch 7/25, Train Loss: 515.1651
# Epoch 8/25, Train Loss: 515.1069
# Epoch 9/25, Train Loss: 515.0531
# Epoch 10/25, Train Loss: 514.9852
# Epoch 11/25, Train Loss: 514.9050
# Epoch 12/25, Train Loss: 514.8777
# Epoch 13/25, Train Loss: 514.8278
# Epoch 14/25, Train Loss: 514.7685
# Epoch 15/25, Train Loss: 514.7563
# Epoch 16/25, Train Loss: 514.6906
# Epoch 17/25, Train Loss: 514.7173
# Epoch 18/25, Train Loss: 514.6551
# Epoch 19/25, Train Loss: 514.5950
# Epoch 20/25, Train Loss: 514.5672
# Epoch 21/25, Train Loss: 514.5841
# Epoch 22/25, Train Loss: 514.5088
# Epoch 23/25, Train Loss: 514.4890
# Epoch 24/25, Train Loss: 514.4692
# Epoch 25/25, Train Loss: 514.4028

# %%
#epoch 50
epochs = 50
vae,train_losses = train(vae, train_data,epochs)
plot_latent(vae, test_data)
plot_reconstructed(vae, test_data)
plot_generated(vae)
# Out:
# Epoch 1/50, Train Loss: 513.6074
# Epoch 2/50, Train Loss: 513.6251
# Epoch 3/50, Train Loss: 513.5835
# Epoch 4/50, Train Loss: 513.6498
# Epoch 5/50, Train Loss: 513.5978
# Epoch 6/50, Train Loss: 513.5925
# Epoch 7/50, Train Loss: 513.6520
# Epoch 8/50, Train Loss: 513.6450
# Epoch 9/50, Train Loss: 513.5925
# Epoch 10/50, Train Loss: 513.5542
# Epoch 11/50, Train Loss: 513.6858
# Epoch 12/50, Train Loss: 513.6099
# Epoch 13/50, Train Loss: 513.6035
# Epoch 14/50, Train Loss: 513.5735
# Epoch 15/50, Train Loss: 513.5502
# Epoch 16/50, Train Loss: 513.5813
# Epoch 17/50, Train Loss: 513.5644
# Epoch 18/50, Train Loss: 513.5416
# Epoch 19/50, Train Loss: 513.5822
# Epoch 20/50, Train Loss: 513.5346
# Epoch 21/50, Train Loss: 513.5287
# Epoch 22/50, Train Loss: 513.5746
# Epoch 23/50, Train Loss: 513.5524
# Epoch 24/50, Train Loss: 513.5462
# Epoch 25/50, Train Loss: 513.5507
# Epoch 26/50, Train Loss: 513.5025
# Epoch 27/50, Train Loss: 513.5591
# Epoch 28/50, Train Loss: 513.5438
# Epoch 29/50, Train Loss: 513.5166
# Epoch 30/50, Train Loss: 513.5388
# Epoch 31/50, Train Loss: 513.5432
# Epoch 32/50, Train Loss: 513.5940
# Epoch 33/50, Train Loss: 513.5593
# Epoch 34/50, Train Loss: 513.5688
# Epoch 35/50, Train Loss: 513.5479
# Epoch 36/50, Train Loss: 513.5135
# Epoch 37/50, Train Loss: 513.5424
# Epoch 38/50, Train Loss: 513.5158
# Epoch 39/50, Train Loss: 513.5136
# Epoch 40/50, Train Loss: 513.5074
# Epoch 41/50, Train Loss: 513.5205
# Epoch 42/50, Train Loss: 513.4839
# Epoch 43/50, Train Loss: 513.4889
# Epoch 44/50, Train Loss: 513.4603
# Epoch 45/50, Train Loss: 513.4870
# Epoch 46/50, Train Loss: 513.4905
# Epoch 47/50, Train Loss: 513.5376
# Epoch 48/50, Train Loss: 513.5475
# Epoch 49/50, Train Loss: 513.5575
# Epoch 50/50, Train Loss: 513.5378
